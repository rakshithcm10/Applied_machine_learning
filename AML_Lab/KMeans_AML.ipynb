# %%
import numpy as np
import pandas as pd
import sklearn as sk

import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs, make_circles

from sklearn.cluster import KMeans

# %% [markdown]
# ##### Synthetic data with different range

# %%
blob_centers = np.array(
    [[ 11.2,  6.3],
     [-1.0 ,  6.3],
     [-4.7,  7.8],
     [-8.0,  12.8],
     [-12.5,  13.3]])

blob_std = np.array([0.4, 0.3, 0.6, 0.1, 0.2])

# %%
X, y = make_blobs(n_samples=300, centers=blob_centers,
                  cluster_std=blob_std, random_state=7)

# %%
def plot_clusters(X, y=None):
    #plt.scatter(X[:, 0], X[:, 1], c=y, s=1)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=1, cmap='rainbow')
    plt.xlabel("$x_1$", fontsize=14)
    plt.ylabel("$x_2$", fontsize=14, rotation=0)

# %%
plot_clusters(X, y)

# %%
##### Synthetic data for KMeans

# %%
num_clusters = 4
X, y = make_blobs(n_samples=300, centers=num_clusters, cluster_std=0.6, random_state=0)
plot_clusters(X, y)

# %%
kmeans = KMeans(n_clusters=num_clusters, random_state=42, verbose=1)
kmeans.fit(X)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 372.7584962032832.
# Iteration 1, inertia 212.600460915319.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 409.28050865481555.
# Iteration 1, inertia 213.5235524997021.
# Iteration 2, inertia 212.0706628599574.
# Iteration 3, inertia 212.00599621083478.
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 328.6200758542842.
# Iteration 1, inertia 212.95128994351143.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 286.557274032127.
# Iteration 1, inertia 212.96867251062508.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 363.29799108982667.
# Iteration 1, inertia 212.32534163947722.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 480.68102747604263.
# Iteration 1, inertia 214.86557472943457.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 472.7342241670585.
# Iteration 1, inertia 224.97712575001918.
# Iteration 2, inertia 212.0706628599574.
# Iteration 3, inertia 212.00599621083478.
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 420.93794216121154.
# Iteration 1, inertia 213.395400071146.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 260.7582419410008.
# Iteration 1, inertia 212.00599621083478.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 336.9840942579653.
# Iteration 1, inertia 212.2476370941977.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# KMeans(n_clusters=4, random_state=42, verbose=1)

# %%
y_pred = kmeans.predict(X)

print("X[i] belongs to cluster:\n", y_pred)
# Out:
# X[i] belongs to cluster:
#  [0 2 1 2 0 0 3 1 2 2 3 2 1 2 0 1 1 0 3 3 0 0 1 3 3 1 0 1 3 1 2 2 1 2 2 2 2
#  2 3 0 1 3 1 1 3 3 2 3 2 0 3 0 2 0 0 3 2 3 2 0 2 1 2 3 3 3 2 0 2 3 1 3 2 3
#  3 2 3 1 0 2 0 1 0 0 2 1 0 1 2 2 1 0 2 3 3 1 0 0 1 3 2 0 2 0 1 0 0 1 2 1 3
#  3 0 2 0 1 2 0 0 1 3 0 3 0 0 0 0 3 0 3 2 3 3 0 2 3 3 2 1 2 2 3 1 3 1 3 2 1
#  2 2 2 1 2 1 0 3 2 3 0 1 2 1 1 0 1 3 3 1 0 1 1 2 0 1 3 2 0 0 1 3 0 1 3 3 1
#  1 1 1 0 2 1 3 1 1 3 3 3 1 3 2 1 3 0 3 1 2 3 2 1 2 1 3 1 1 2 3 3 0 0 1 2 0
#  0 3 0 3 1 2 2 1 1 2 1 0 3 1 0 3 2 3 0 1 0 2 2 2 2 3 3 2 1 3 0 1 3 3 3 0 0
#  2 1 1 3 0 2 3 1 2 1 0 0 3 3 1 0 0 0 1 2 2 0 0 1 0 0 0 2 3 2 1 0 0 2 2 2 0
#  0 1 2 3]

# %%
print("Instance labels:\n", kmeans.labels_)
print("Cluster Centroids:\n", kmeans.cluster_centers_)
print("Inertia: ", kmeans.inertia_)
# Out:
# Instance labels:
#  [0 2 1 2 0 0 3 1 2 2 3 2 1 2 0 1 1 0 3 3 0 0 1 3 3 1 0 1 3 1 2 2 1 2 2 2 2
#  2 3 0 1 3 1 1 3 3 2 3 2 0 3 0 2 0 0 3 2 3 2 0 2 1 2 3 3 3 2 0 2 3 1 3 2 3
#  3 2 3 1 0 2 0 1 0 0 2 1 0 1 2 2 1 0 2 3 3 1 0 0 1 3 2 0 2 0 1 0 0 1 2 1 3
#  3 0 2 0 1 2 0 0 1 3 0 3 0 0 0 0 3 0 3 2 3 3 0 2 3 3 2 1 2 2 3 1 3 1 3 2 1
#  2 2 2 1 2 1 0 3 2 3 0 1 2 1 1 0 1 3 3 1 0 1 1 2 0 1 3 2 0 0 1 3 0 1 3 3 1
#  1 1 1 0 2 1 3 1 1 3 3 3 1 3 2 1 3 0 3 1 2 3 2 1 2 1 3 1 1 2 3 3 0 0 1 2 0
#  0 3 0 3 1 2 2 1 1 2 1 0 3 1 0 3 2 3 0 1 0 2 2 2 2 3 3 2 1 3 0 1 3 3 3 0 0
#  2 1 1 3 0 2 3 1 2 1 0 0 3 3 1 0 0 0 1 2 2 0 0 1 0 0 0 2 3 2 1 0 0 2 2 2 0
#  0 1 2 3]
# Cluster Centroids:
#  [[ 1.98258281  0.86771314]
#  [ 0.94973532  4.41906906]
#  [-1.37324398  7.75368871]
#  [-1.58438467  2.83081263]]
# Inertia:  212.00599621083478

# %%
X_new = np.array([[0, 2], [3, 2], [-3, 1], [-3, 2.5]])
kmeans.predict(X_new)
# Out:
# array([3, 0, 3, 3])

# %% [markdown]
# **Outlier analysis**

# %%
X_clust1=X[kmeans.labels_==1] #data points belongs to cluster numbered 1
X_clust1[:5]
# Out:
# array([[1.15521298, 5.09961887],
#        [1.41372442, 4.38117707],
#        [1.24258802, 4.50399192],
#        [0.45379179, 3.95647753],
#        [1.06923853, 4.53068484]])

# %%
mean1 =np.mean(X_clust1,axis=0)
var1= np.var(X_clust1,axis=0)
mean1, var1
# Out:
# (array([0.94973532, 4.41906906]), array([0.36494083, 0.34558283]))

# %%
#cov_matrix=np.array([var1[0],?],[?,var1[1]])

# %%
from sklearn.covariance import EllipticEnvelope

mcd =EllipticEnvelope(random_state=0).fit(X_clust1)
mcd
# Out:
# EllipticEnvelope(random_state=0)

# %%
def Mahalanobis_distance(X):
    pass

# %% [markdown]
# ##### Utility functions for plotting

# %%
def plot_data(X):
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='o', s=30, linewidths=8,
                color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=50, linewidths=50,
                color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
        plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)

# %%
#KMeans producing a linear decision boundary
plt.figure(figsize=(12, 6))
plot_decision_boundaries(kmeans, X)
plt.show()

# %%
def plot_clusterer_comparison(clusterer1, clusterer2, X, title1=None, title2=None):
    clusterer1.fit(X)
    clusterer2.fit(X)

    plt.figure(figsize=(12, 4))

    plt.subplot(121)
    plot_decision_boundaries(clusterer1, X)
    if title1:
        plt.title(title1, fontsize=14)

    plt.subplot(122)
    plot_decision_boundaries(clusterer2, X, show_ylabels=False)
    if title2:
        plt.title(title2, fontsize=14)

# %%
kmeans_rnd_init1 = KMeans(n_clusters=5, init="random", n_init=1,
                         algorithm="full", random_state=11)
kmeans_rnd_init2 = KMeans(n_clusters=5, init="random", n_init=1,
                         algorithm="full", random_state=19)

plot_clusterer_comparison(kmeans_rnd_init1, kmeans_rnd_init2, X,
                          "Solution 1", "Solution 2 (with a different random init)")

plt.show()
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
kmeans_rnd_init1 = KMeans(n_clusters=5, init="k-means++", n_init=1,
                         algorithm="full", random_state=11)
kmeans_rnd_init2 = KMeans(n_clusters=5, init="k-means++", n_init=1,
                         algorithm="full", random_state=19)

plot_clusterer_comparison(kmeans_rnd_init1, kmeans_rnd_init2, X,
                          "Solution 1", "Solution 2 (with a different random init)")
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
#   0.77364764  0.05422228 -0.0121455   0.43987676  0.63075028  0.74681961
#   0.56061469  0.56722218  0.42262759  0.42633433  0.19307744  0.74178662
#   0.70648884  0.64088069  0.72993704  0.36293334  0.47504258  0.75453211
#   0.63985037  0.42766971  0.36461594  0.41101621  0.60891696  0.72481166
#   0.38431553  0.77672981  0.78562961  0.61291065  0.44639217  0.20102553
#   0.38502217  0.02586924  0.65636494  0.76097102  0.21743099  0.18250734
#   0.2233859   0.65097791  0.67990422  0.44968155  0.37282455  0.74293195]

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,8))
for i in [2, 3, 4, 5]:
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
# ##### Poor man's Image segmentation

# %%
from matplotlib.image import imread
from pylab import *

plt.figure(figsize=(8, 4))
image = imread("1207513.jpg") 
imshow(image)
show()

print("Image Shape (3D Array): ", image.shape)
image.dtype
# Out:
# Image Shape (3D Array):  (1342, 2208, 3)
# dtype('uint8')

# %%
X = image.reshape(-1, 3)
print("Dimension of Reshaped X: ", X.shape)
# Out:
# Dimension of Reshaped X:  (2963136, 3)

# %%
kmeans = KMeans(n_clusters=8, random_state=42).fit(X)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
print(f"Label count= {kmeans.labels_.shape}")
print("3D Cluster Center count=", kmeans.cluster_centers_.shape)
print("3D Cluster Centers:\n", kmeans.cluster_centers_)
# Out:
# Label count= (2963136,)
# 3D Cluster Center count= (8, 3)
# 3D Cluster Centers:
#  [[200.61786792 227.88879508 231.8983388 ]
#  [ 92.51309932  86.33697103  82.23392799]
#  [ 65.84571062  59.34032709  56.17088036]
#  [172.73575275 155.45200313 145.4722287 ]
#  [175.60688112  13.38939889  26.58955832]
#  [ 25.64230335  18.70211983  18.57498616]
#  [109.66446782 111.18012193 113.45585852]
#  [141.19774809 204.91796465 217.1797957 ]]

# %%
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image)
plt.title("Original image")
plt.axis('off')

plt.subplot(122)
#plt.imshow(segmented_img/255)
plt.imshow((segmented_img * 255).astype(np.uint8))
plt.title("Segmented Image: {} colors".format(8))
show()

# %% [markdown]
# ##### MNIST

# %%
from sklearn.datasets import load_digits

# %%
X_digits, y_digits = load_digits(return_X_y=True)

print(X_digits.shape)
# Out:
# (1797, 64)

# %%
some_digit = X_digits[16]
some_digit_image = some_digit.reshape(8, 8)
plt.imshow(some_digit_image, cmap = 'gray', interpolation="nearest")
plt.show()

# %%
def visualize_digit(img):
    fig = plt.figure(figsize = (8,8)) 
    img = img.reshape(8, 8)
    plt.imshow(img, cmap='gray')
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            plt.annotate(str(round(img[x][y],2)), xy=(y,x),
                        horizontalalignment='center',
                        verticalalignment='center',
                        color='white' if img[x][y]<thresh else 'black')

visualize_digit(X_digits[16])

# %% [markdown]
# **Kmeans for MNIST**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_digits, y_digits, random_state=42)
print(f"X_train dim {X_train.shape}")
# Out:
# X_train dim (1347, 64)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(multi_class="ovr", solver="lbfgs", max_iter=5000, random_state=42)
lr.fit(X_train, y_train)

accuracy_before_preproc = lr.score(X_test, y_test)
print(f"Accuracy before preproc = {accuracy_before_preproc}")
# Out:
# Accuracy before preproc = 0.9688888888888889

# %% [markdown]
# ##### KMeans for preprocessing

# %%
# Step 1: Choose a number of clusters to be the projected dimension of our features and train the K-Means model.
kmeans = KMeans(n_clusters=50, random_state=42)
kmeans.fit(X_train)


# Step 2: Compute the distance of the data points from each cluster center. 
#         These distances will be the new feature vector.
X_train_new = kmeans.transform(X_train)
X_test_new = kmeans.transform(X_test)

print("Dimension of new features: ", X_train_new.shape)

# Classify the data using the new features
log_reg = LogisticRegression(multi_class="ovr", solver="lbfgs", max_iter=5000, random_state=42)
log_reg.fit(X_train_new, y_train)


accuracy_after_preproc = log_reg.score(X_test_new, y_test)
print("Accuracy after preproc = ", accuracy_after_preproc)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# Dimension of new features:  (1347, 50)
# Accuracy after preproc =  0.9733333333333334

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ("kmeans", KMeans(n_clusters=50, random_state=42)),
    ("lr", LogisticRegression(multi_class="ovr", solver="lbfgs", max_iter=5000, random_state=42)),
])
pipeline.fit(X_train, y_train)

accuracy_after_preproc = pipeline.score(X_test, y_test)

print(f"Accuracy after preproc = {accuracy_after_preproc}")

reduction_in_error = 1 - (1 - accuracy_after_preproc) / (1 - accuracy_before_preproc)
print("Reduction in Error Rate: %f" %  reduction_in_error)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# Accuracy after preproc = 0.9733333333333334
# Reduction in Error Rate: 0.142857

# %%
from sklearn.model_selection import GridSearchCV
param_grid = dict(kmeans__n_clusters=range(2, 100))
grid_clf = GridSearchCV(pipeline, param_grid, cv=3, verbose=1, n_jobs=-1)
grid_clf.fit(X_train, y_train)

params_optimal_grid_clf = grid_clf.best_params_

print("Optimal Hyperparameter Values: ", params_optimal_grid_clf)
print("Grid Accuracy: ", grid_clf.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 98 candidates, totalling 294 fits
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# Optimal Hyperparameter Values:  {'kmeans__n_clusters': 79}
# Grid Accuracy:  0.9844444444444445

# %%
print("Optimal Number of Clusters: ", params_optimal_grid_clf['kmeans__n_clusters'])

pipeline = Pipeline([
    ("kmeans", KMeans(n_clusters=params_optimal_grid_clf['kmeans__n_clusters'], random_state=42)),
    ("log_reg", LogisticRegression(multi_class="ovr", solver="lbfgs", max_iter=5000, random_state=42)),
])
pipeline.fit(X_train, y_train)

accuracy_after_preproc = pipeline.score(X_test, y_test)

print("Accuracy after preproc: ", accuracy_after_preproc)

reduction_in_error = 1 - (1 - accuracy_after_preproc) / (1 - accuracy_before_preproc)
print("Reduction in Error Rate: %f" %  reduction_in_error)
# Out:
# Optimal Number of Clusters:  79
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# Accuracy after preproc:  0.9844444444444445
# Reduction in Error Rate: 0.500000

# %% [markdown]
# ##### Gaussian Mixture Models

# %%
X1, y1 = make_blobs(n_samples=1000, centers=((4, -4), (0, 0)), random_state=42)
X1 = X1.dot(np.array([[0.374, 0.95], [0.732, 0.598]]))
X2, y2 = make_blobs(n_samples=250, centers=1, random_state=42)
X2 = X2 + [6, -8]
X = np.r_[X1, X2]
y = np.r_[y1, y2]

# %%
def plot_clusters(X, y=None):
    plt.scatter(X[:, 0], X[:, 1], c=y, s=5, cmap='autumn')
    plt.xlabel("$x_1$", fontsize=14)
    plt.ylabel("$x_2$", fontsize=14, rotation=0)
    
plt.figure(figsize=(12, 6))
plot_clusters(X)
plt.show()
# Out:
# C:\Users\appur\AppData\Local\Temp\ipykernel_7392\3765311429.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], c=y, s=5, cmap='autumn')

# %%
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=3, n_init=10, random_state=42)
gmm.fit(X)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# GaussianMixture(n_components=3, n_init=10, random_state=42)

# %%
dir(gmm)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_parameters',
#  '_compute_lower_bound',
#  '_e_step',
#  '_estimate_log_prob',
#  '_estimate_log_prob_resp',
#  '_estimate_log_weights',
#  '_estimate_weighted_log_prob',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_parameters',
#  '_get_tags',
#  '_initialize',
#  '_initialize_parameters',
#  '_m_step',
#  '_more_tags',
#  '_n_parameters',
#  '_parameter_constraints',
#  '_print_verbose_msg_init_beg',
#  '_print_verbose_msg_init_end',
#  '_print_verbose_msg_iter_end',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_parameters',
#  '_validate_data',
#  '_validate_params',
#  'aic',
#  'bic',
#  'converged_',
#  'covariance_type',
#  'covariances_',
#  'fit',
#  'fit_predict',
#  'get_metadata_routing',
#  'get_params',
#  'init_params',
#  'lower_bound_',
#  'max_iter',
#  'means_',
#  'means_init',
#  'n_components',
#  'n_features_in_',
#  'n_init',
#  'n_iter_',
#  'precisions_',
#  'precisions_cholesky_',
#  'precisions_init',
#  'predict',
#  'predict_proba',
#  'random_state',
#  'reg_covar',
#  'sample',
#  'score',
#  'score_samples',
#  'set_params',
#  'tol',
#  'verbose',
#  'verbose_interval',
#  'warm_start',
#  'weights_',
#  'weights_init']

# %%
from matplotlib.colors import LogNorm
def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='o', s=30, linewidths=8,
                color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=50, linewidths=50,
                color=cross_color, zorder=11, alpha=1)


def plot_gaussian_mixture(clusterer, X, resolution=1000, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = -clusterer.score_samples(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z,
                 norm=LogNorm(vmin=1.0, vmax=30.0),
                 levels=np.logspace(0, 2, 12))
    plt.contour(xx, yy, Z,
                norm=LogNorm(vmin=1.0, vmax=30.0),
                levels=np.logspace(0, 2, 12),
                linewidths=1, colors='k')

    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contour(xx, yy, Z,
                linewidths=2, colors='r', linestyles='dashed')
    
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)
    plot_centroids(clusterer.means_, clusterer.weights_)

    plt.xlabel("$x_1$", fontsize=14)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)

# %%
# Compute the log-likelihood of each sample
densities = gmm.score_samples(X)

# Define the threshold is at the fourth percentile lowest density
density_threshold = np.percentile(densities, 4) 

# Get the anomalous samples
anomalies = X[densities < density_threshold]

# %%
plt.figure(figsize=(12, 6))
plt.title("Anomalies (red stars) Reside in the Low-Density Regions")

plot_gaussian_mixture(gmm, X)
plt.scatter(anomalies[:, 0], anomalies[:, 1], color='r', marker='*')
plt.ylim(top=5.1)

plt.show()

# %% [markdown]
# ##### Decision boundary for mixture models

# %%
X1, y1 = make_blobs(n_samples=1000, centers=((4, -4), (0, 0)), random_state=42)
X1 = X1.dot(np.array([[0.374, 0.95], [0.732, 0.598]]))
X2, y2 = make_blobs(n_samples=250, centers=1, random_state=42)
X2 = X2 + [6, -8]
X = np.r_[X1, X2]
y = np.r_[y1, y2]


plt.figure(figsize=(12, 6))
plt.scatter(X[:, 0], X[:, 1], c=None, s=2, cmap='autumn')
plt.xlabel("$x_1$", fontsize=14)
plt.ylabel("$x_2$", fontsize=14, rotation=0)
plt.show()
# Out:
# C:\Users\appur\AppData\Local\Temp\ipykernel_7392\3823662884.py:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], c=None, s=2, cmap='autumn')

# %%
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X)
                for k in range(1, 10)]



silhouette_scores = [silhouette_score(X, model.labels_)
                     for model in kmeans_per_k[1:]]

plt.figure(figsize=(10, 4))
plt.plot(range(2, 10), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.show()
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %%
# Number of clusters
k = 3

# Train the K-Means model
kmeans = KMeans(n_clusters=k, random_state=42, verbose=1)
kmeans.fit(X)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 3225.780627369329.
# Iteration 1, inertia 2268.408032763855.
# Iteration 2, inertia 2243.22457572225.
# Iteration 3, inertia 2242.570890040229.
# Converged at iteration 3: center shift 0.00011244051617867288 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 3209.0799025215774.
# Iteration 1, inertia 2255.6749038134817.
# Iteration 2, inertia 2245.370207646302.
# Iteration 3, inertia 2243.258517821495.
# Iteration 4, inertia 2242.61791300434.
# Converged at iteration 4: center shift 0.00015645458208555786 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2761.4096253754915.
# Iteration 1, inertia 2370.7957799508176.
# Iteration 2, inertia 2268.916345578315.
# Iteration 3, inertia 2249.8015979338147.
# Iteration 4, inertia 2244.8631097533535.
# Iteration 5, inertia 2242.76034661873.
# Converged at iteration 5: center shift 0.000257640008785334 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2686.08752238972.
# Iteration 1, inertia 2251.862859806111.
# Iteration 2, inertia 2245.3912301795517.
# Iteration 3, inertia 2243.258517821495.
# Iteration 4, inertia 2242.61791300434.
# Converged at iteration 4: center shift 0.00015645458208556005 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 3411.5936305087466.
# Iteration 1, inertia 2359.3218968893043.
# Iteration 2, inertia 2265.1603252787327.
# Iteration 3, inertia 2222.5799759074507.
# Iteration 4, inertia 2200.5101485014106.
# Iteration 5, inertia 2190.0292424378877.
# Iteration 6, inertia 2183.761982539717.
# Iteration 7, inertia 2181.1314966697487.
# Iteration 8, inertia 2180.2453166875516.
# Iteration 9, inertia 2179.7652903510093.
# Converged at iteration 9: center shift 0.0001943577507456419 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2995.9776361849013.
# Iteration 1, inertia 2510.8543900414597.
# Iteration 2, inertia 2382.0836841149157.
# Iteration 3, inertia 2266.0020846898.
# Iteration 4, inertia 2249.1692385454453.
# Iteration 5, inertia 2244.5223595504085.
# Iteration 6, inertia 2242.7603466187297.
# Converged at iteration 6: center shift 0.00025764000878533407 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 3250.6942525921036.
# Iteration 1, inertia 2201.7805222698225.
# Iteration 2, inertia 2192.7122493583993.
# Iteration 3, inertia 2187.175853166799.
# Iteration 4, inertia 2182.5815229123073.
# Iteration 5, inertia 2180.670868132259.
# Converged at iteration 5: center shift 0.0002191811631445882 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 3974.5991543077685.
# Iteration 1, inertia 2331.108751307526.
# Iteration 2, inertia 2261.8067767029133.
# Iteration 3, inertia 2248.311378416485.
# Iteration 4, inertia 2243.8601347868375.
# Iteration 5, inertia 2242.76034661873.
# Converged at iteration 5: center shift 0.00025764000878533065 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2909.2075282488818.
# Iteration 1, inertia 2279.366170067633.
# Iteration 2, inertia 2243.8425824252.
# Iteration 3, inertia 2242.4849352206834.
# Iteration 4, inertia 2242.223762064598.
# Converged at iteration 4: center shift 0.00016224575535147526 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2745.0014038821982.
# Iteration 1, inertia 2264.7373825672507.
# Iteration 2, inertia 2250.6139050521056.
# Iteration 3, inertia 2246.545980346487.
# Iteration 4, inertia 2243.6143795365997.
# Iteration 5, inertia 2242.4938983349984.
# Iteration 6, inertia 2242.2364469468052.
# Converged at iteration 6: center shift 0.00014141231205052956 within tolerance 0.0002732132474543051.
# KMeans(n_clusters=3, random_state=42, verbose=1)

# %%
plt.figure(figsize=(12, 6))
plt.title("Clustering by K-Means")
plot_decision_boundaries(kmeans, X)
plt.show()

# %%
gm = GaussianMixture(n_components=3, n_init=10)
gm.fit(X)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# GaussianMixture(n_components=3, n_init=10)

# %%
plt.figure(figsize=(12, 6))
plt.title("Clustering by GMM")
plot_decision_boundaries(gm, X, show_centroids=False)
plt.show()

# %% [markdown]
# ##### DBSCAN for non globular data

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=1000, noise=0.05, random_state=42)


plt.figure(figsize=(12, 6))
plt.scatter(X[:, 0], X[:, 1], c=None, s=5, cmap='autumn')
plt.title("Two Arbitrary Shape Clusters", fontsize=16)
plt.xlabel("$x_1$", fontsize=14)
plt.ylabel("$x_2$", fontsize=14, rotation=0)
plt.show()
# Out:
# C:\Users\appur\AppData\Local\Temp\ipykernel_7392\780380561.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], c=None, s=5, cmap='autumn')

# %%
# Number of clusters
k = 2

# Train the K-Means model
kmeans = KMeans(n_clusters=k, random_state=42, verbose=1)
kmeans.fit(X)
# Out:
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\appur\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 619.3335316073201.
# Iteration 1, inertia 453.9120517375721.
# Iteration 2, inertia 419.47875248888107.
# Iteration 3, inertia 408.46583239850895.
# Iteration 4, inertia 404.8714787620756.
# Iteration 5, inertia 403.9369135342487.
# Iteration 6, inertia 403.7193772760851.
# Converged at iteration 6: center shift 2.8537666641003462e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 652.694065837828.
# Iteration 1, inertia 469.60960067333593.
# Iteration 2, inertia 424.82059674900876.
# Iteration 3, inertia 408.656093434788.
# Iteration 4, inertia 405.2298963160256.
# Iteration 5, inertia 404.5220164249544.
# Iteration 6, inertia 404.2149303070103.
# Iteration 7, inertia 403.9691541573959.
# Iteration 8, inertia 403.761720068842.
# Iteration 9, inertia 403.69348228643315.
# Converged at iteration 9: center shift 2.756458158079779e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia